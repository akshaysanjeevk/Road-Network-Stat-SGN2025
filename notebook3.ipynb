# %%
import networkx as nx
import osmnx as osm
from fn_lib import * 
from infomap import Infomap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 4
#       2 import osmnx as osm
#       3 from fn_lib import *
# ----> 4 from infomap import Infomap
#
# ModuleNotFoundError: No module named 'infomap'

# %%
G0 = OpenGraph("CHE")

# %%
im = Infomap("--directed")

for u, v, d in G.edges(data=True):
    im.addLink(u, v, d.get("weight", 1.0))

im.run()

# %%
pip install infomap
# Out:
# ...
#   Using cached infomap-2.8.0.tar.gz (264 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build infomap
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for infomap (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       <string>:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#       Building with OpenMP support
# ...
